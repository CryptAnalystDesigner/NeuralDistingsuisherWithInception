# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 12
pairs = 8
# fig, ax = plt.subplots() 
y = np.load("simon_data_wrong_key_mean_"+str(rounds)+"r_pairs"+str(pairs)+".npy")
# ax.plot(range(2**16), y)
# fig.savefig(str(rounds)+"_round_simon.pdf")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
# plt.plot(range(0,2**16,8), y[::8])
plt.plot(range(0,2**16), y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 11
pairs = 8
fig, ax = plt.subplots() 
y = np.load("simon_data_wrong_key_mean_"+str(rounds)+"r_pairs"+str(pairs)+".npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 12
pairs = 8
fig, ax = plt.subplots() 
y = np.load("simon_data_wrong_key_mean_"+str(rounds)+"r_pairs"+str(pairs)+".npy")
ax.plot(range(2**16), y)

# %%
from math import log2
z= 0.5405250035556531
neutral_bits = 64
log2(z/(1-z))*neutral_bits
# Out:
# 14.999999999999961

# %%
vtmp=122
neutral_bits = 64
x=2**(vtmp/neutral_bits)
x/(1+x)
# Out:
# 0.7893998752167426

# %%
from math import log2
log2(2**28*(38848/0.2)/(225/0.52)*64)
# Out:
# 52.81028313829238

# %%
from math import log2,log
log2(2**(28)*1168*log(0.01,(1-0.72))*500/225)
# Out:
# 41.19688860602287

# %%
log2(2**(44.21)*1*log(0.01,(1-0.49)))
# Out:
# 46.98383764063718

# %%
from math import log2,log
log(0.01,(1-0.2))
# Out:
# 20.637702317032343
