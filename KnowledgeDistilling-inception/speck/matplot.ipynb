# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_7r_num_epochs20_acc_0.8128569722175598_data_wrong_key_mean_7r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_7r_num_epochs40_acc_0.805361_data_wrong_key_mean_7r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 7
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_7r_num_epochs20_acc_0.8128569722175598_data_wrong_key_mean_7r_pairs8.npy")
y1 = np.load(wdir+"speck_model_7r_num_epochs40_acc_0.805361_data_wrong_key_mean_7r_pairs8.npy")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y)
plt.plot(range(0,2**16), y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 7
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_7r_num_epochs20_acc_0.8128569722175598_data_wrong_key_mean_7r_pairs8.npy")
y1 = np.load(wdir+"speck_model_7r_num_epochs40_acc_0.799585_data_wrong_key_mean_7r_pairs8.npy")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y-y1)
# plt.plot(range(0,2**16), y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 7

y = np.load(wdir+"speck_model_7r_num_epochs40_acc_0.805361_data_wrong_key_mean_7r_pairs8.npy")
y1 = np.load(wdir+"speck_model_7r_num_epochs20_acc_0.8128569722175598_data_wrong_key_mean_7r_pairs8.npy")

plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y)
plt.plot(range(0,2**16), y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 7
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_7r_num_epochs20_acc_0.8128569722175598_data_wrong_key_mean_7r_pairs8.npy")
y1 = np.load(wdir+"speck_model_7r_num_epochs40_acc_0.805361_data_wrong_key_mean_7r_pairs8.npy")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y1-y)
# plt.plot(range(0,2**16), y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.5532829761505127_data_wrong_key_mean_8r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.5416589975357056_data_wrong_key_mean_8r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 7
y = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.540369987487793_data_wrong_key_mean_8r_pairs8.npy")
y1 = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.5532829761505127_data_wrong_key_mean_8r_pairs8.npy")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y)
plt.plot(range(0,2**16), y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = 8
wdir = "./wkrp/"
y = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.5418319702148438_data_wrong_key_mean_8r_pairs8.npy")
y1 = np.load(wdir+"speck_model_8r_num_epochs10_acc_0.5532829761505127_data_wrong_key_mean_8r_pairs8.npy")
plt.figure(figsize=(12,8))
plt.xticks(np.arange(0,65537,4096))
plt.plot(range(0,2**16), y1-y)
# plt.plot(range(0,2**16), y1)
plt.show()
