# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"simon_model_10r_num_epochs40_acc_0.676828_data_wrong_key_mean_10r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"simon_model_11r_num_epochs40_acc_0.558271_data_wrong_key_mean_11r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
wdir = "./wkrp/"
y = np.load(wdir+"simon_model_12r_num_epochs10_acc_0.5086619853973389_data_wrong_key_mean_12r_pairs8.npy")
ax.plot(range(2**16), y)
