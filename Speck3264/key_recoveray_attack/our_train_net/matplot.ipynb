# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
y = np.load("data_wrong_key_mean_8r_pairs8.npy")
ax.plot(range(2**16), y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots() 
y = np.load("transfer_learning_data_wrong_key_mean_8r_pairs8.npy")
y2 = np.tile(np.array([0.5016]),2**16)
ax.plot(range(2**16), y)
ax.plot(range(2**16), y2)

# %%
from math import log2
z= 0.493
neutral_bits = 512
log2(z/(1-z))*neutral_bits
# Out:
# -20.68382752021966

# %%
vtmp=8
neutral_bits = 512
x=2**(vtmp/neutral_bits)
x/(1+x)
# Out:
# 0.5027075797079513

# %%
from math import log2
log2(2**38*(38848/0.2)/(225/0.52)*64)
# Out:
# 52.81028313829238
